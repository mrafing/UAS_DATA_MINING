# %%
#import library penting
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 

# %matplotlib inline

# %%
#load dataset
data = pd.read_csv('Heart Dataset.csv')
data
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
#cek jumlah data dan kolomnya
data.shape
# Out:
# (303, 14)

# %%
## Step EDA

# %%
#cek data kosong
data.isnull().values.any()
# Out:
# False

# %%
#Korelasi menggunakan heatmap
import seaborn as sns 

korelasi = data.corr()
features = korelasi.index
plt.figure(figsize=(20,20))

#plot heat map
g=sns.heatmap(data[features].corr(),annot=True,cmap="RdYlGn")

# %%
#Show corellation in tables
data.corr()
# Out:
#                age       sex        cp    trtbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trtbps    0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalachh -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exng      0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slp      -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# caa       0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thall     0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
#statistika dasar
data.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
#checking skewness dari data
heart_true_count =len(data.loc[data['output']==1])
heart_false_count = len(data.loc[data['output']==0])

# %%
#view
(heart_true_count,heart_false_count)
# Out:
# (165, 138)

# %%
#Missing value
print('total number of rows : {0}'.format(data.shape[0]))
print('total number of columns : {0}'.format(data.shape[1]))
# Out:
# total number of rows : 303
# total number of columns : 14

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
print('Banyak baris nilai nol untuk umur :{0}'.format(len(data.loc[data['age']==0])))
print('Banyak baris nilai nol untuk Jenis Kelamin :{0}'.format(len(data.loc[data['sex']==0])))
print('Banyak baris nilai nol untuk nyeri dada :{0}'.format(len(data.loc[data['cp']==0])))
print('Banyak baris nilai nol untuk tekanan darah :{0}'.format(len(data.loc[data['trtbps']==0])))
print('Banyak baris nilai nol untuk kolestrol :{0}'.format(len(data.loc[data['chol']==0])))
print('Banyak baris nilai nol untuk gula darah :{0}'.format(len(data.loc[data['fbs']==0])))
print('Banyak baris nilai nol untuk resting electrocardiographic :{0}'.format(len(data.loc[data['restecg']==0])))
print('Banyak baris nilai nol untuk denyut jantung maksimal :{0}'.format(len(data.loc[data['thalachh']==0])))
print('Banyak baris nilai nol untuk angina :{0}'.format(len(data.loc[data['exng']==0])))
print('Banyak baris nilai nol untuk oldpeak :{0}'.format(len(data.loc[data['oldpeak']==0])))
print('Banyak baris nilai nol untuk Kemiringan segmen ST latihan. :{0}'.format(len(data.loc[data['slp']==0])))
print('Banyak baris nilai nol untuk caa :{0}'.format(len(data.loc[data['caa']==0])))
print('Banyak baris nilai nol untuk thall :{0}'.format(len(data.loc[data['thall']==0])))
# Out:
# Banyak baris nilai nol untuk umur :0
# Banyak baris nilai nol untuk Jenis Kelamin :96
# Banyak baris nilai nol untuk nyeri dada :143
# Banyak baris nilai nol untuk tekanan darah :0
# Banyak baris nilai nol untuk kolestrol :0
# Banyak baris nilai nol untuk gula darah :258
# Banyak baris nilai nol untuk resting electrocardiographic :147
# Banyak baris nilai nol untuk denyut jantung maksimal :0
# Banyak baris nilai nol untuk angina :204
# Banyak baris nilai nol untuk oldpeak :99
# Banyak baris nilai nol untuk Kemiringan segmen ST latihan. :21
# Banyak baris nilai nol untuk caa :175
# Banyak baris nilai nol untuk thall :2

# %%
data2 = data.copy()

# %%
#rata-rata
avg_age = data2['age'].mean()
avg_trtbps = data2['trtbps'].mean()
avg_chol = data2['chol'].mean()
avg_thalachh = data2['thalachh'].mean()
avg_oldpeak = data2['oldpeak'].mean()

# %%
#now replace avg to columns 
data2['age'].replace({0:avg_age},inplace=True)
data2['trtbps'].replace({0:avg_trtbps},inplace=True)
data2['chol'].replace({0:avg_chol},inplace=True)
data2['thalachh'].replace({0:avg_thalachh},inplace=True)
data2['oldpeak'].replace({0:avg_oldpeak},inplace=True)

# %%
#double check
print('Banyak baris nilai nol untuk umur :{0}'.format(len(data.loc[data2['age']==0])))
print('Banyak baris nilai nol untuk Jenis Kelamin :{0}'.format(len(data.loc[data2['sex']==0])))
print('Banyak baris nilai nol untuk nyeri dada :{0}'.format(len(data.loc[data2['cp']==0])))
print('Banyak baris nilai nol untuk tekanan darah :{0}'.format(len(data.loc[data2['trtbps']==0])))
print('Banyak baris nilai nol untuk kolestrol :{0}'.format(len(data.loc[data2['chol']==0])))
print('Banyak baris nilai nol untuk gula darah :{0}'.format(len(data.loc[data2['fbs']==0])))
print('Banyak baris nilai nol untuk resting electrocardiographic :{0}'.format(len(data.loc[data2['restecg']==0])))
print('Banyak baris nilai nol untuk denyut jantung maksimal :{0}'.format(len(data.loc[data2['thalachh']==0])))
print('Banyak baris nilai nol untuk angina :{0}'.format(len(data.loc[data2['exng']==0])))
print('Banyak baris nilai nol untuk oldpeak :{0}'.format(len(data.loc[data2['oldpeak']==0])))
print('Banyak baris nilai nol untuk Kemiringan segmen ST latihan. :{0}'.format(len(data.loc[data2['slp']==0])))
print('Banyak baris nilai nol untuk caa :{0}'.format(len(data.loc[data2['caa']==0])))
print('Banyak baris nilai nol untuk thall :{0}'.format(len(data.loc[data2['thall']==0])))
# Out:
# Banyak baris nilai nol untuk umur :0
# Banyak baris nilai nol untuk Jenis Kelamin :96
# Banyak baris nilai nol untuk nyeri dada :143
# Banyak baris nilai nol untuk tekanan darah :0
# Banyak baris nilai nol untuk kolestrol :0
# Banyak baris nilai nol untuk gula darah :258
# Banyak baris nilai nol untuk resting electrocardiographic :147
# Banyak baris nilai nol untuk denyut jantung maksimal :0
# Banyak baris nilai nol untuk angina :204
# Banyak baris nilai nol untuk oldpeak :0
# Banyak baris nilai nol untuk Kemiringan segmen ST latihan. :21
# Banyak baris nilai nol untuk caa :175
# Banyak baris nilai nol untuk thall :2

# %%
#make pairplot
sns.pairplot(data2,hue='output',palette='magma',height=3.5)
plt.tight_layout()

# %%
#joinplot
sns.jointplot(x='age',y='output',data=data2,height=10,kind='kde',color='blue')
plt.tight_layout()

# %%
from sklearn.model_selection import train_test_split

X = data2.drop('output',axis=1)
y = data2['output']

# %%
X
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng   oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0  2.300000    0
# 1     37    1   2     130   250    0        1       187     0  3.500000    0
# 2     41    0   1     130   204    0        0       172     0  1.400000    2
# 3     56    1   1     120   236    0        1       178     0  0.800000    2
# 4     57    0   0     120   354    0        1       163     1  0.600000    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...       ...  ...
# 298   57    0   0     140   241    0        1       123     1  0.200000    1
# 299   45    1   3     110   264    0        1       132     0  1.200000    1
# 300   68    1   0     144   193    1        1       141     0  3.400000    1
# 301   57    1   0     130   131    0        1       115     1  1.200000    1
# 302   57    0   1     130   236    0        0       174     0  1.039604    1
#
#      caa  thall
# 0      0      1
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: output, Length: 303, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %%
X_train
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng   oldpeak  slp  \
# 132   42    1   1     120   295    0        1       162     0  1.039604    2
# 202   58    1   0     150   270    0        0       111     1  0.800000    2
# 196   46    1   2     150   231    0        1       147     0  3.600000    1
# 75    55    0   1     135   250    0        0       161     0  1.400000    1
# 176   60    1   0     117   230    1        1       160     1  1.400000    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...       ...  ...
# 188   50    1   2     140   233    0        1       163     0  0.600000    1
# 71    51    1   2      94   227    0        1       154     1  1.039604    2
# 106   69    1   3     160   234    1        0       131     0  0.100000    1
# 270   46    1   0     120   249    0        0       144     0  0.800000    2
# 102   63    0   1     140   195    0        1       179     0  1.039604    2
#
#      caa  thall
# 132    0      2
# ...

# %%
X_train.shape
# Out:
# (242, 13)

# %%
y_train.shape
# Out:
# (242,)

# %%
X_test
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng   oldpeak  slp  \
# 179   57    1   0     150   276    0        0       112     1  0.600000    1
# 228   59    1   3     170   288    0        0       159     0  0.200000    1
# 111   57    1   2     150   126    1        1       173     0  0.200000    2
# 246   56    0   0     134   409    0        0       150     1  1.900000    1
# 60    71    0   2     110   265    1        0       130     0  1.039604    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...       ...  ...
# 249   69    1   2     140   254    0        0       146     0  2.000000    1
# 104   50    1   2     129   196    0        1       163     0  1.039604    2
# 300   68    1   0     144   193    1        1       141     0  3.400000    1
# 193   60    1   0     145   282    0        0       142     1  2.800000    1
# 184   50    1   0     150   243    0        0       128     0  2.600000    1
#
#      caa  thall
# 179    1      1
# ...

# %%
y_train
# Out:
# 132    1
# 202    0
# 196    0
# 75     1
# 176    0
#       ..
# 188    0
# 71     1
# 106    1
# 270    0
# 102    1
# Name: output, Length: 242, dtype: int64

# %%
# from sklearn.svm import SVC
# SVC_model = SVC()

from sklearn.neighbors import KNeighborsClassifier
KNN_model = KNeighborsClassifier()

# %%
# SVC_model.fit(X_train,y_train)
KNN_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# svc_prediction = SVC_model.predict(X_test)
knn_prediction = KNN_model.predict(X_test)

# %%
# from sklearn.metrics import classification_report, confusion_matrix
# print(confusion_matrix(y_test,svc_prediction))

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, knn_prediction))
# Out:
# [[19 10]
#  [ 8 24]]

# %%
# print(classification_report(y_test,svc_prediction))
print(classification_report(y_test, knn_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.66      0.68        29
#            1       0.71      0.75      0.73        32
#
#     accuracy                           0.70        61
#    macro avg       0.70      0.70      0.70        61
# weighted avg       0.70      0.70      0.70        61

# %%
# Menyimpan model KNN ke dalam file pickle
import pickle
pickle.dump(KNN_model, open('KNN_model.pkl', 'wb'))
